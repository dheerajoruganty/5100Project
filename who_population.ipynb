# %%
import pandas as pd

pop = pd.read_csv('API_SP.POP.TOTL_DS2_en_csv_v2_6011311.csv')
print(pop.columns)
# Out:
# Index(['Country Name', 'Country Code', 'Indicator Name', 'Indicator Code',
#        '1960', '1961', '1962', '1963', '1964', '1965', '1966', '1967', '1968',
#        '1969', '1970', '1971', '1972', '1973', '1974', '1975', '1976', '1977',
#        '1978', '1979', '1980', '1981', '1982', '1983', '1984', '1985', '1986',
#        '1987', '1988', '1989', '1990', '1991', '1992', '1993', '1994', '1995',
#        '1996', '1997', '1998', '1999', '2000', '2001', '2002', '2003', '2004',
#        '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013',
#        '2014', '2015', '2016', '2017', '2018', '2019', '2020', '2021', '2022',
#        'Unnamed: 67'],
#       dtype='object')

# %%
pop = pop[['Country Name', 'Country Code', 'Indicator Name', '2000', '2001',
           '2002', '2003', '2004', '2005', '2006', '2007', '2008', '2009', '2010',
           '2011', '2012', '2013', '2014', '2015', '2016', '2017', '2018', '2019',
           '2020', '2021', '2022']]

print(pop.head())
# Out:
#                   Country Name Country Code     Indicator Name         2000  \
# 0                        Aruba          ABW  Population, total      89101.0
# 1  Africa Eastern and Southern          AFE  Population, total  401600588.0
# 2                  Afghanistan          AFG  Population, total   19542982.0
# 3   Africa Western and Central          AFW  Population, total  269611898.0
# 4                       Angola          AGO  Population, total   16394062.0
#
#           2001         2002         2003         2004         2005  \
# 0      90691.0      91781.0      92701.0      93540.0      94483.0
# 1  412001885.0  422741118.0  433807484.0  445281555.0  457153837.0
# 2   19688632.0   21000256.0   22645130.0   23553551.0   24411191.0
# 3  277160097.0  284952322.0  292977949.0  301265247.0  309824829.0
# 4   16941587.0   17516139.0   18124342.0   18771125.0   19450959.0
#
#           2006  ...         2013         2014         2015         2016  \
# ...
